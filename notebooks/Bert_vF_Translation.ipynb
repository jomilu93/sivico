# %% [markdown]
# # Bert Test (with translation)

# %% [markdown]
# ## Import librares for notebook.

# %%
import torch
import nltk
from transformers import BertTokenizer, BertModel
from nltk.tokenize import sent_tokenize
from googletrans import Translator
import pandas as pd
import numpy as np
from deep_translator import GoogleTranslator
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Import and translate data

# %%
#Import senator csv from senator_data_file
senators = pd.read_csv(r'senators_data.csv', converters={'initiative_list': pd.eval})

# %%
#Split the concatenated initiatives for each senator into bites smaller than 5000 to be able to translate.
senators["initiatives_summary_dummy_split"] = ""

n = 4999

for i, row in senators.iterrows():
    if not row["initiative_list"] == []:
        initiatives_split = [row["initiatives_summary_dummy"][i:i+n] for i in range(0, len(row["initiatives_summary_dummy"]), n)]
        senators.at[i, "initiatives_summary_dummy_split"] = initiatives_split
    else:
        senators.at[i, "initiatives_summary_dummy_split"] = []

# %%
#Translate the concatenated, split string of initiatives per senator, store in new column.

senators["initiatives_summary_dummy_split_en"] = ""

for i, row in senators.iterrows():
    print(f"Working on row {i} of {len(senators)}")
    if len(row["initiatives_summary_dummy_split"]) >= 1:
        en_initiatives = GoogleTranslator(source='es', target='en').translate_batch(row["initiatives_summary_dummy_split"])
        senators.at[i, "initiatives_summary_dummy_split_en"] = en_initiatives
        print(f"Summary {i} translated successfully. Sample: {en_initiatives[0][:20]}")
    else:
        print(f"Senator number {i}, senator {row['senadores']} has no initiatives to translate.")
        continue
# Out:
# Working on row 0 of 126
# Summary 0 translated successfully. Sample: It intends to guaran
# Working on row 1 of 126
# Summary 1 translated successfully. Sample: It proposes that the
# Working on row 2 of 126
# Summary 2 translated successfully. Sample: Proposes to modify t
# Working on row 3 of 126
# Summary 3 translated successfully. Sample: It proposes to elimi
# Working on row 4 of 126
# Summary 4 translated successfully. Sample: Proposes to modify t
# Working on row 5 of 126
# Summary 5 translated successfully. Sample: Proposes to modify t
# Working on row 6 of 126
# Summary 6 translated successfully. Sample: It proposes to repea
# Working on row 7 of 126
# Summary 7 translated successfully. Sample: It proposes to add a
# Working on row 8 of 126
# Summary 8 translated successfully. Sample: It proposes to deter
# Working on row 9 of 126
# Summary 9 translated successfully. Sample: It proposes to estab
# Working on row 10 of 126
# Summary 10 translated successfully. Sample: Proposes that the Mi
# Working on row 11 of 126
# Summary 11 translated successfully. Sample: It proposes that dur
# Working on row 12 of 126
# Summary 12 translated successfully. Sample: It proposes to estab
# Working on row 13 of 126
# Summary 13 translated successfully. Sample: Proposes to modify t
# Working on row 14 of 126
# Summary 14 translated successfully. Sample: Proposes to modify t
# Working on row 15 of 126
# Summary 15 translated successfully. Sample: Proposes to modify t
# Working on row 16 of 126
# Summary 16 translated successfully. Sample: Proposes to modify t
# Working on row 17 of 126
# Summary 17 translated successfully. Sample: It proposes to estab
# Working on row 18 of 126
# Summary 18 translated successfully. Sample: It proposes to estab
# Working on row 19 of 126
# Summary 19 translated successfully. Sample: It proposes to issue
# Working on row 20 of 126
# Summary 20 translated successfully. Sample: Proposes to modify t
# Working on row 21 of 126
# Summary 21 translated successfully. Sample: Proposes to modify t
# Working on row 22 of 126
# Summary 22 translated successfully. Sample: It proposes to deter
# Working on row 23 of 126
# Summary 23 translated successfully. Sample: It proposes to estab
# Working on row 24 of 126
# Summary 24 translated successfully. Sample: It proposes to estab
# Working on row 25 of 126
# Summary 25 translated successfully. Sample: Proposes to modify t
# Working on row 26 of 126
# Summary 26 translated successfully. Sample: Proposes to modify t
# Working on row 27 of 126
# Summary 27 translated successfully. Sample: It proposes to estab
# Working on row 28 of 126
# Summary 28 translated successfully. Sample: It proposes to estab
# Working on row 29 of 126
# Summary 29 translated successfully. Sample: It proposes to repea
# Working on row 30 of 126
# Summary 30 translated successfully. Sample: It proposes to issue
# Working on row 31 of 126
# Summary 31 translated successfully. Sample: Proposes issuing the
# Working on row 32 of 126
# Summary 32 translated successfully. Sample: Proposes to modify t
# Working on row 33 of 126
# Summary 33 translated successfully. Sample: Proposes to modify t
# Working on row 34 of 126
# Summary 34 translated successfully. Sample: Proposes that the Mi
# Working on row 35 of 126
# Summary 35 translated successfully. Sample: It proposes issuing
# Working on row 36 of 126
# Summary 36 translated successfully. Sample: It proposes to estab
# Working on row 37 of 126
# Summary 37 translated successfully. Sample: It proposes to estab
# Working on row 38 of 126
# Summary 38 translated successfully. Sample: It proposes that the
# Working on row 39 of 126
# Summary 39 translated successfully. Sample: It proposes to estab
# Working on row 40 of 126
# Summary 40 translated successfully. Sample: Proposes that the Bo
# Working on row 41 of 126
# Summary 41 translated successfully. Sample: Proposes to modify t
# Working on row 42 of 126
# Summary 42 translated successfully. Sample: It proposes to estab
# Working on row 43 of 126
# Summary 43 translated successfully. Sample: Proposes to modify t
# Working on row 44 of 126
# Summary 44 translated successfully. Sample: Proposes to regulate
# Working on row 45 of 126
# Summary 45 translated successfully. Sample: It proposes to issue
# Working on row 46 of 126
# Summary 46 translated successfully. Sample: It proposes to issue
# Working on row 47 of 126
# Summary 47 translated successfully. Sample: It proposes to issue
# Working on row 48 of 126
# Summary 48 translated successfully. Sample: It proposes to issue
# Working on row 49 of 126
# Summary 49 translated successfully. Sample: It proposes issuing
# Working on row 50 of 126
# Summary 50 translated successfully. Sample: It proposes to issue
# Working on row 51 of 126
# Summary 51 translated successfully. Sample: It proposes to estab
# Working on row 52 of 126
# Summary 52 translated successfully. Sample: It proposes to issue
# Working on row 53 of 126
# Summary 53 translated successfully. Sample: Proposes to modify t
# Working on row 54 of 126
# Summary 54 translated successfully. Sample: Proposes to issue th
# Working on row 55 of 126
# Summary 55 translated successfully. Sample: It proposes to issue
# Working on row 56 of 126
# Summary 56 translated successfully. Sample: It proposes to issue
# Working on row 57 of 126
# Summary 57 translated successfully. Sample: It proposes to creat
# Working on row 58 of 126
# Summary 58 translated successfully. Sample: ONLY. - The Head of
# Working on row 59 of 126
# Summary 59 translated successfully. Sample: It proposes that in
# Working on row 60 of 126
# Summary 60 translated successfully. Sample: It proposes to estab
# Working on row 61 of 126
# Summary 61 translated successfully. Sample: It proposes to allow
# Working on row 62 of 126
# Summary 62 translated successfully. Sample: It proposes to creat
# Working on row 63 of 126
# Summary 63 translated successfully. Sample: It proposes to estab
# Working on row 64 of 126
# Summary 64 translated successfully. Sample: It adds as a matter
# Working on row 65 of 126
# Summary 65 translated successfully. Sample: Proposes to regulate
# Working on row 66 of 126
# Summary 66 translated successfully. Sample: It proposes to estab
# Working on row 67 of 126
# Summary 67 translated successfully. Sample: It proposes to estab
# Working on row 68 of 126
# Summary 68 translated successfully. Sample: Proposes to eliminat
# Working on row 69 of 126
# Summary 69 translated successfully. Sample: Proposes to regulate
# Working on row 70 of 126
# Summary 70 translated successfully. Sample: It proposes establis
# Working on row 71 of 126
# Summary 71 translated successfully. Sample: Proposes to issue th
# Working on row 72 of 126
# Summary 72 translated successfully. Sample: It proposes to estab
# Working on row 73 of 126
# Summary 73 translated successfully. Sample: Proposes to issue th
# Working on row 74 of 126
# Summary 74 translated successfully. Sample: It proposes to estab
# Working on row 75 of 126
# Summary 75 translated successfully. Sample: It proposes to estab
# Working on row 76 of 126
# Summary 76 translated successfully. Sample: It proposes to estab
# Working on row 77 of 126
# Summary 77 translated successfully. Sample: Proposes that the Mi
# Working on row 78 of 126
# Summary 78 translated successfully. Sample: It proposes to estab
# Working on row 79 of 126
# Summary 79 translated successfully. Sample: Proposes to issue th
# Working on row 80 of 126
# Summary 80 translated successfully. Sample: It proposes to estab
# Working on row 81 of 126
# Summary 81 translated successfully. Sample: Proposes to issue th
# Working on row 82 of 126
# Senator number 82, senator Alejandro Rojas Diaz Duran has no initiatives to translate.
# Working on row 83 of 126
# Summary 83 translated successfully. Sample: It proposes to estab
# Working on row 84 of 126
# Summary 84 translated successfully. Sample: It proposes to estab
# Working on row 85 of 126
# Summary 85 translated successfully. Sample: It proposes to estab
# Working on row 86 of 126
# Summary 86 translated successfully. Sample: Proposes that the pr
# Working on row 87 of 126
# Summary 87 translated successfully. Sample: It proposes the modi
# Working on row 88 of 126
# Summary 88 translated successfully. Sample: Proposes issuing the
# Working on row 89 of 126
# Summary 89 translated successfully. Sample: It proposes to incre
# Working on row 90 of 126
# Summary 90 translated successfully. Sample: It proposes establis
# Working on row 91 of 126
# Summary 91 translated successfully. Sample: It proposes empoweri
# Working on row 92 of 126
# Summary 92 translated successfully. Sample: It proposes to estab
# Working on row 93 of 126
# Summary 93 translated successfully. Sample: Proposes to issue th
# Working on row 94 of 126
# Summary 94 translated successfully. Sample: It proposes to estab
# Working on row 95 of 126
# Summary 95 translated successfully. Sample: It proposes to estab
# Working on row 96 of 126
# Summary 96 translated successfully. Sample: It proposes to estab
# Working on row 97 of 126
# Summary 97 translated successfully. Sample: It proposes to estab
# Working on row 98 of 126
# Summary 98 translated successfully. Sample: It proposes to estab
# Working on row 99 of 126
# Summary 99 translated successfully. Sample: Proposes to issue th
# Working on row 100 of 126
# Summary 100 translated successfully. Sample: Proposes a reduction
# Working on row 101 of 126
# Summary 101 translated successfully. Sample: It proposes to estab
# Working on row 102 of 126
# Summary 102 translated successfully. Sample: It proposes to estab
# Working on row 103 of 126
# Summary 103 translated successfully. Sample: Proposes to establis
# Working on row 104 of 126
# Summary 104 translated successfully. Sample: Proposes that the Na
# Working on row 105 of 126
# Summary 105 translated successfully. Sample: It proposes to estab
# Working on row 106 of 126
# Summary 106 translated successfully. Sample: Proposes that the Na
# Working on row 107 of 126
# Summary 107 translated successfully. Sample: It proposes to estab
# Working on row 108 of 126
# Summary 108 translated successfully. Sample: It proposes to estab
# Working on row 109 of 126
# Summary 109 translated successfully. Sample: Proposes to issue th
# Working on row 110 of 126
# Summary 110 translated successfully. Sample: It proposes to estab
# Working on row 111 of 126
# Summary 111 translated successfully. Sample: Proposes to issue th
# Working on row 112 of 126
# Summary 112 translated successfully. Sample: It proposes to estab
# Working on row 113 of 126
# Summary 113 translated successfully. Sample: It proposes to estab
# Working on row 114 of 126
# Summary 114 translated successfully. Sample: Proposes to issue th
# Working on row 115 of 126
# Summary 115 translated successfully. Sample: It proposes to estab
# Working on row 116 of 126
# Summary 116 translated successfully. Sample: The purpose of the i
# Working on row 117 of 126
# Summary 117 translated successfully. Sample: It proposes to estab
# Working on row 118 of 126
# Summary 118 translated successfully. Sample: Proposes that the ad
# Working on row 119 of 126
# Summary 119 translated successfully. Sample: It proposes establis
# Working on row 120 of 126
# Summary 120 translated successfully. Sample: It proposes to estab
# Working on row 121 of 126
# Summary 121 translated successfully. Sample: It proposes to estab
# Working on row 122 of 126
# Summary 122 translated successfully. Sample: Proposes to issue th
# Working on row 123 of 126
# Summary 123 translated successfully. Sample: Proposes to add exto
# Working on row 124 of 126
# Summary 124 translated successfully. Sample: It proposes to estab
# Working on row 125 of 126
# Senator number 125, senator José Ramón Gómez Leal has no initiatives to translate.

# %%
#Join all split, translated initiatives into one long english string per senator.

senators["initiatives_summary_dummy_en"] = senators["initiatives_summary_dummy_split_en"].apply(lambda x: "".join(x))

# %%
senators["initiatives_summary_dummy_split_en"][3]
# Out:
# ['It proposes to eliminate the requirement that establishes that it is necessary for plant workers to have at least 15 years of seniority in employment, in order to receive a seniority premium in the event of voluntary separation from the same. It proposes to eliminate the assumption that determines that when proceeds to a commercial trial and the conventional address agreed to receive notifications does not correspond to that of the claim, notification is made by edicts without the need to obtain the report that the public authority or institution must prepare when the judge so orders. Proposes establish that independent workers who were not included in insurance under the voluntary regime or who have ceased to be, may be subject to insurance under the mandatory regime; states that, in order to enjoy benefits for unemployment of advanced age, the worker will have to have covered 750 weekly contributions. In addition, it establishes that when the mother or father of a newborn has him or her exclusively under their care and therefore has to leave the labor market, the weeks of contribution will be considered completed during that time for up to a period of one year. Likewise, it proposes that the insured who opt for old-age insurance and who have not met the required contribution weeks may withdraw the balance of their individual account in a single payment or continue contributing until the necessary weeks are covered. Finally, it proposes that, within the Retirement Savings Systems, the investment regime must have as its main objective to grant the highest profitability, without sacrificing the future purchasing power of the expected return. It proposes to establish that the administrators of the individual accounts and that channel the resources of the sub-accounts of the workers must operate and pay in a prompt and expeditious manner the programmed withdrawals or partial withdrawals; proposes that after completing the processes duly, the Social Security Institutes, having authorization to the AFORE, will have a maximum of 15 days to make the transfers. It proposes to repeal article 115 of the Credit Institutions Law by which it empowered the Ministry of Finance and Public Credit to issue a list of people blocked for the purpose of suspending services, freezing bank accounts that has the scope of an investigation technique or precautionary measure without any intervention from the Public Ministry. Being included in the list of blocked persons is of course the incrimination of the probable commission of a crime, which is why the competent authorities in criminal matters are the ones that must deal with the investigation of the crime and not the tax authority who invades functions of the Public Ministry. It proposes to modify the treatment of crimes against freedom of expression, specifically when using violence to avoid the exercise of journalistic activity and when freedom of expression is hindered. The penalty for whoever commits them will be from nine months to four years in prison and two hundred to three hundred days of fine; If the crime is committed by a public servant in the exercise of their functions or there are gender reasons in the commission of the crime, the penalty will increase by up to one half. It proposes to prohibit the concessionaire or permit holder of air services from the second sale of a segment of a ticket with connection. It proposes to specify a term of up to ten business days for the National Insurance and Bonds Commission to establish the respective fine when resolving in cases of claims. It proposes to establish regulatory measures in order to prohibit the manufacture, import, distribution, offer, sale and use of electronic aerosol administration systems, understood as electronic devices through which a solution is heated that generates an aerosol that is inhaled by a person. Proposes the imprescriptibility of sexual crimes or human trafficking committed by adolescents against girls, boys, adol ...
#  "ntara in a quarter or if the victim is under fifteen years old or cannot understand the meaning of the fact, the penalty will increase by up to half. It proposes to set specific deadlines for the days to make complaints, claims, assistance before the Federal Consumer Attorney's Office and that it can give an immediate solution, under the determination of its various procedures through the request of the parties involved. It proposes that, in the debate procedure, in the case of reserved articles or additions, the president of the Senate will proceed to the consultation of the author or representative of the authors, if the addition or reservation of an article is continued or withdrawn. It proposes that parliamentary control be carried out on appointments by the federal executive and the procedure for the selection of ministers of the Supreme Court of Justice of the Nation Establish the parameters for the procedure for the issuance of an agreement issued by the Senate of the Republic for the election of ministers and the appointment of a technical committee made up of 7 people elected by the Senate's management body, by the Human Rights Commission, by the President of the Republic, by the National Electoral Institute and another by the Guarantor Body contemplated in article six of the Constitution. It proposes that the Congress of the Union be governed by the principles of an Open Parliament, based on the transparency of information , accountability and promotion of citizen participation, with the application of information technologies. Authorizes the Secretary of Parliamentary Services of the Chamber of Deputies to prepare and propose to the Secretary General the guidelines for Open Parliament and the Biannual Action Plan. Thus, it also proposes that the Open Parliament Services include the design, implementation and evaluation of their own mechanisms. Finally, it claims that within the attributions that the Secretary General of the Chamber will be to present to the Conference, the guidelines of the Open Parliament and the Biannual Action Plan on the matter. It proposes to eliminate the prescription in favor of the National Fund for Housing on the resources of the worker's housing sub-account. Proposes that Amaranth be considered a basic and strategic product for the State to procure its supply. Establishes that the interest for debtors who delay in the payment of their debts must not exceed the thirty percent per year. In the case of loans in titles or securities, the yield for arrears will be the one that the same titles or securities accrue, not exceeding thirty percent per year. It proposes that, in the cases in which the Federal Institute of Telecommunications determines that there is no public interest In order to recover the concessioned radio spectrum, it will grant extensions upon request, as long as the concessionaire accepts the new conditions established by the Institute, among which the payment of a consideration will be included. It proposes that in the case of serious crimes committed by adolescents between 16 and and 17 years of age, the maximum limits of the custodial sentence will be for a maximum period of eight years. It proposes to establish that one to six years in prison and a fine of three hundred to six hundred days will be imposed on whoever reveals, discloses , transfer to third parties, improperly use to the detriment of another, information, images or audiovisual recordings obtained even with their consent or in a private communication intervention, out of the reach of the gaze of third parties and using broadcasting, telecommunications, computer media or any other means of data transmission that seriously undermines the personal privacy of the affected party. Likewise, when the crime is committed by the spouse or by a person who is or has been united by an affective relationship or for profit, the penalty will be increased by up to a third to establish it. It proposes the representation of the ...
#  'n Inventories of Rural Warehouses, and - Establish the supervision of the Federal Government through the Ministry of Agriculture, Livestock, Rural Development, Fisheries and Food, regarding the management of stocks of Storeable Products stored in facilities authorized and certified to operate as Warehouses Rural. Likewise, it intends to reform the Sustainable Rural Development Law to harmonize the legal framework. It proposes to establish that in no case will access to the voting screens be allowed to people who carry cell phones, cameras, video recording cameras, scanners, or any electronic device that presumes it may contribute to the performance of any fraudulent activity. It proposes to incorporate electricity generation from clean energies, in accordance with the Energy Transition Law, in what is applicable as one more of the powers of the federation in energy matters. It proposes that the sale and dispensing of pesticides must be carried out through the display of a certificate issued by a specialist. It proposes that the SHCP establish "General Rules" and that through them the usual commercialization or intermediation or professional of precious metals, precious stones, jewels or watches, in which operations of purchase or sale of said goods are involved through acts or operations in cash; They will be notified to the SHCP when the person carrying out said activities carries out a cash operation with a client for an amount equal to or greater than that determined by the SHCP; and finally that through said "General Rules" an activity be considered vulnerable to transfers of ownership of watches, jewelry, Precious Metals and Precious Stones, either by piece or by lot, and works of art. It proposes that the Financial entities are prohibited from charging commissions to clients or users for the opening of any type of payroll account, being exempt from any commission for withdrawals and inquiries, as well as insurance or any other concept that the banking institution grants to the account. It proposes that the volume product of sanitation, reuse, care and efficient management of water is not considered for purposes of payment of the non-expiration guarantee fee, because said fee scares away new investments and discourages saving water. Proposes that the Protection System Integral\'s function is to promote, in the three levels of government, the uninterrupted and sufficient establishment of budgets for the protection of the rights of girls, boys and adolescents. The purpose of this initiative is to establish the period of half an hour from the originally established the call until the lifting of the session if the necessary quorum is not gathered. He proposes to specify that the primary productive process based on renewable natural resources such as agriculture, includes innocuous crops on land and in inert substrates without soil. He proposes the creation of a New Body Public Finance Technician of the Federal Legislative Power with the main function of generating information, analysis and data on national public finances based on technical studies, which serve as parliamentary support for decision-making in both Chambers according to the powers of each legislative body. This proposal includes the following attributes for the formation of the body: a) Legal nature;\r\nb) Principles of action, and\r\nc) Attributions\r\nThe Law that is intended to be issued is intended to establish and regulate the organization and operation of Rural Warehouses, as well as their duly authorized facilities throughout the national territory, seeks to promote and regulate the activities and operations that Rural Warehouses may carry out for the due reception, collection, handling, control, storage or conservation of Storeable Products. Proposes to regulate the Rural Storage service aimed at the storage, custody and conservation of Storeable Products, as well as the activities derived from the provisions contained in this Law and regulate the iss ...
#  'e expropriation of their land, succeed their land rights and alienate their land rights. It proposes to establish that the provision of constantly updated education must contribute to the integral and permanent development so that they are people with significant, relevant and useful knowledge, as well as school professionals highly qualified with high humanistic and social sense. academic coordinators, managers, teachers and specialists in educational matters will participate in the preparation of study plans and programs. It proposes to establish in current legislation that the access of women in situations of violence to social programs for the purpose of economic strengthening is guaranteed , psychological and legal. It proposes to include in the purposes that agricultural associations will have, promoting research in terms of both chemical and organic fertilization to manage and promote conservation and sustainability agriculture. It proposes to establish that suppliers that sell computers, mobile applications, any type of electronic commerce must ensure the delivery of the good or service to the consumer; allow making claims and returns; cover transportation costs and shipment of merchandise; and previously inform the consumer of the price, approximate delivery date, insurance and freight costs.\r\nIt proposes that the promotion of entrepreneurship, the promotion and learning of the culture of savings and financial education must be integrated by the basic elements of finance in general and personal finance in the contents of the study plans and programs taught by the State. It proposes to establish that the criteria contained in the statutes of national sports associations that favor the hiring of foreign professional athletes over nationals will be null. It proposes to establish that the National Policy on Equality between women and men will include the promotion of the participation and recognition of those women that operate in the health sector. It proposes to establish that the Public Institutions of the Health Sector must provide an appropriate response from health services to the particularities of older adults with disabilities and provide them with access to technological devices with the purpose of allowing their inclusion, independence and participation in society activities. It proposes that the educational authorities provide the adequate infrastructure in the creation of educational spaces according to the needs of the community, the geography and the environment, being optimal to ensure the integrity and well-being of students, teachers and any member of the educational space at all times.\r\nAs well as, guarantee with said infrastructure, full accessibility for people with disabilities.\r\nProposes increasing up to sixteen years in prison and up to eight hundred days a fine for anyone who without right forces another to give, do, stop doing or tolerate something, obtaining a profit for himself or for another or causing someone financial or moral damage, with violence or intimidation. It proposes to establish that the activities focused on promoting the process of social and economic transformation of the rural population will be understood under the correct distribution of resources, equally considering women and youth from rural regions of the country. The priority actions aimed at sustainable rural development must be fulfilled promptly, projecting results and impacts of the budgetary exercise. It proposes determining that the development of new national technologies (fertilizers, pesticides and other products that benefit the countryside and its workers) should be promoted. In addition, it specifies that the Agricultural Associations will have the purpose of promoting research for chemical and organic fertilization to generate conservation and sustainability agriculture. It proposes establishing that the Ministry of Economy must seek to promote financial and digital education, which focuses on savin ...
#  "oso.Proposes establishing various measures that promote road safety such as the training of people who drive double-trailer or double-articulated vehicles. Determine how driving under the influence of alcohol or drugs is grounds for driver's license revocation. It contemplates that federal and private passenger, tourism and cargo motor transport vehicles must have a video device on the front to record the movement of the vehicle. The Ministry of Communications and Transportation will take measures to rigorously verify and control the weights and dimensions of cargo transportation vehicles on federal roads, so it must have all the necessary resources for it. Likewise, the Secretariat is empowered to carry out Road Safety inspections in order to reduce road accidents. It proposes to add to the Law the figure of Media Representative or Manager, who will be the person who represents the media in order to manage contracts publicidades.ÚNICO.- The Senate of the Republic respectfully urges the Ministry of Environment and Natural Resources and the National Water Commission, to inform this Sovereignty about the actions and measures that have been implemented to solve the water conflict generated in the states of Jalisco and Guanajuato by the Decree declaring the National Superficial Water Reserve in the Verde River Basin, in the Official Gazette of the Federation on April 7, 1995. ONLY. The Permanent Commission of the H. Congress of the Union: a) expresses its appreciation to the Government of the Republic and, in particular, to the Ministry of Foreign Affairs and the structure of diplomatic and consular representations of our country abroad, for the actions undertaken to affirm the policies for the protection of the rights of our compatriots residing abroad, as well as to facilitate the safe return to our country of those who were outside the national territory when the SARS CoV-2 pandemic was decreed by the World Organization Of the health; b) urges the Ministry of Foreign Affairs to continue with the deployment of consular protection and safe repatriation actions, due to the different determinations of the countries with which we maintain diplomatic relations in matters of mitigation, containment and care of the health emergency; and c) requests the preparation and review of the report on the consular protection and safe repatriation actions that the Ministry of Foreign Affairs has coordinated and carried out, through the structure of diplomatic and consular representations of our country abroad from the declaration of the SARS CoV-2 pandemic by the World Health Organization. FIRST. The Permanent Commission of the Honorable Congress of the Union respectfully exhorts the Ministry of Finance and Public Credit and the Ministry of Health, so that, within the scope of their powers and in a coordinated manner, they initiate economic valuation and budget impact studies!, In order to determine how the Federal Government can ensure the acquisition of sufficient doses of the vaccine under development and the implementation of universal vaccination campaigns against the SARS-CoV-2 virus, which causes the COVID-19 disease, for the fiscal years and expense budgets corresponding to the years 2020 and 2021. SECOND. The Permanent Commission of the H. Congress of the Union respectfully exhorts the Secretary of Finance and Public Credit, the Secretary of Health, the National Institute of Health for Well-being, the Mexican Institute of Social Security, the Institute of Security and Social Services of State Workers, the Social Security Institute for the Armed Forces and the Federal Commission for Protection against Sanitary Risks, so that within the scope of their powers and in a coordinated manner, they carry out the corresponding procedures with International Organizations, national pharmaceutical companies and international, as well as with other research centers to establish the necessary requirements so that Mexico can benefit from the vaccine u ...
#  'The Permanent Commission of the Congress of the Union respectfully urges the Ministry of Environment and Natural Resources, so that, based on its powers, it continues to strengthen biosafety measures and financial and in-kind support programs for all establishments. that protect animal species in the country and that carry out tasks of protection and conservation of wildlife, with the aim of guaranteeing the well-being of animals in captivity. FIRST. The Permanent Commission of the H. Congress of the Union respectfully urges the Attorney General of the Republic, the Secretariat of Security and Citizen Protection, and their counterparts in the federal entities, so that, within the scope of their powers, they strengthen the investigation , persecution, combat and prevention of crimes committed against the girls, boys and adolescents of the country. SECOND. The Permanent Commission of the Honorable Congress of the Union respectfully exhorts the Office of the Attorney General of the Republic, the Secretary of Security and Citizen Protection, and their counterparts in the federal entities, so that, within the scope of their powers, they strengthen the measures of security in technological platforms, in order to prevent the crimes of human trafficking, child pornography, sexual abuse and violence against girls, boys and adolescents. FIRST. The Permanent Commission of the Honorable Congress of the Union, within the scope of collaboration between the Powers, respectfully requests the Ministry of Health and the National Institute of Indigenous Languages, within the scope of their powers and in coordination with the governments of the 32 federal entities, continue to strengthen actions so that indigenous peoples and communities have information and access to materials in their different languages, to prevent the COVID -19 disease. SECOND. The Permanent Commission of the Honorable Congress of the Union respectfully urges the National Council to Prevent Discrimination to promote actions to facilitate and provide people of African descent with official materials and communications related to the COVID-19 disease. UNIQUE. The Permanent Commission of the H. Congress of the Union respectfully exhorts all the instances that are members of the National System to Prevent, Attend, Punish and Eradicate Violence against Women and the systems of the 32 federal entities, to continue with the strengthening actions of the programs and mechanisms to prevent, address, punish and eradicate violence against women and girls.\r\nFIRST. The Permanent Commission of the H. Congress of the Union recognizes and values \u200b\u200bthe vocation, dedication and commitment of professional medical, nursing and health personnel during the extraordinary demands to which they have been subjected in the face of the SARS-CoV2 virus pandemic (Covid-19). Without your determination and spirit of service, it would be morally and practically impossible to provide the population with the care it requires. SECOND. The Permanent Commission of the Honorable Congress of the Union strongly condemns the attacks and violence against the physical and psychological integrity of professional medical, nursing and health personnel that unfortunately have occurred in various parts of the country. THIRD. The Permanent Commission of the H. Congress of the Union requests the competent authorities for the administration of justice at the federal level and of the federative entities, to follow up on the complaints of physical and psychological aggressions, as well as the incidents of violence exerted against of professional medical, nursing and health personnel in order to determine responsibilities and present the accusations before the judicial authority. ROOM. The Permanent Commission of the H. Congress of the Union exhorts the Ministry of the Interior to reinforce the awareness, empathy, solidarity and recognition campaigns of the society with the professional personnel of medicine, the nur ...
#  'announces the Quota to import, with Tariff-Established Quota, Chicken Meat, published in the Official Gazette of the Federation on May 16, 2013 and whose expiration will take place on December 31, 2019, as well as its possible effects or benefits to the national and family economy, making it known to this Sovereignty. SECOND. The Senate of the Republic, in the scope of the collaboration between the Powers of the Union, urges the Head of the Executive Power, through the Secretariat and dependencies in the sphere of its competence, to contribute to the promotion and development of the poultry sector. that allows achieving self-sufficiency in terms of chicken meat and its derivatives, as well as verifying that imported chicken meat does not contain hormones and that it complies with quality standards. UNIQUE. The Senate of the Republic congratulates the people of the Principality of Andorra for the free and democratic conduct of their parliamentary elections, while at the same time it wishes to strengthen relations between Mexico and this sister country.\r\nONLY. The Senate of the Republic congratulates the people of the Slovak Republic for the free and democratic conduct of their presidential elections, at the same time that it wishes to strengthen relations between Mexico and this brother country. UNIQUE. · The Senate of The Republic congratulates the people of the Republic of Estonia for the free and democratic conduct of their parliamentary elections, while it wishes for the strengthening of relations between Mexico and this brotherly country. UNIQUE. The Senate of the Republic congratulates the people of the Republic of Finland for the free and democratic conduct of their parliamentary elections, while it wishes to strengthen relations between Mexico and this brother country. UNIQUE. The Senate of the Republic congratulates the people of Ukraine for the free and democratic conduct of their presidential elections, while it wishes to strengthen relations between Mexico and this brother country. FIRST. The Permanent Commission of the Honorable Congress of the Union respectfully exhorts the Technical Committee for Rate Validation in the State of Jalisco to avoid increasing public transportation rates until the quality of the transportation service improves. SECOND. The Permanent Commission of the Honorable Congress of the Union urges the State Human Rights Commission of Jalisco to submit a report on the investigations into possible violations by the state police in the demonstration that took place on July 26, 2019 at the Plaza Universidad station of the Electric Train. THIRD. The Permanent Commission of the Honorable Congress of the Union respectfully exhorts the Government of the State of Jalisco to submit a report on the results of the dialogue roundtables with the population in order to find a mechanism that allows, gradually and effectively, to improve the service of the public transport. UNIQUE. The Senate of the Republic respectfully urges the Ministry of the Environment and Natural Resources and the National Water Commission to send this Sovereignty a report on the progress in the execution of the different water supply infrastructure projects for the states. of Jalisco and Guanajuato, particularly in the region of the Altos de Jalisco and León, as well as the goals and objectives that are being carried out to guarantee the right to water in said federal entities. SOLE.- The Permanent Commission of the H. Congress of the Union respectfully exhorts the Ministry of Agriculture and Rural Development so that, in coordination with the Mexican Food Security agency, it analyzes and, where appropriate, includes crystalline wheat and honey as basic food products in the benefits scheme that offers the UNIQUE Guaranteed Price Program. The Permanent Commission of the Honorable Congress of the Union respectfully requests the Federal Telecommunications Institute to submit a detailed report on the telecommunications and/or broadcasti ...
#  "hermería, dentistry and other areas related to health. UNIQUE. The Senate of the Republic respectfully exhorts the Secretariats of Economy, and of Finance and Public Credit, to consider the necessary measures to mitigate the tariff reduction, as well as to consider entering into agreements with the national footwear sector, to reduce the country cost of Mexico, informing this Sovereignty about the results that, if applicable, were obtained. FIRST. - The secretariats of Welfare and of Finance and Public Credit are urged to provide the necessary information on the modifications to the Children's Day Program, according to the questionnaire presented below. Questionnaire to gather information on the Children's Stays program. Section 1.- Regarding the budget, for both Secretariats (Welfare and Finance)\r\n1. How many children's day care centers operate and how much was allocated to them annually?\r\n2. What is the resource that is assigned for each minor in the Children's Day Program?\r\n3. What is the budget earmarked for day care centers by state and by municipality?\r\n4. What are the reasons that led to the budget cut for the Estancias Infantiles program?\r\n5. When will the support delivery mechanism without intermediaries be implemented? If such deposits have already been made, how many have been made, for what amount and in which states?\r\n6. What will be the mechanism for monitoring public spending to verify the use and implementation of the resource granted in order to avoid the diversion of resources?\r\n7. What will be the destination of the resource cut to the Children's Stays program, under the responsibility of the Secretary of Welfare? Where is it reassigned?\r\n8. We consider it essential that a reform to the Federal Budget and Fiscal Responsibility Law be promoted in section 11 of article 41, to add a subparagraph w) that makes specific reference to the allocation of resources to the item in question and is not subject to the annual whim to earmark funds for this concept of vital importance for Mexican children. What do the heads of the dependencies to whom these questions are addressed think of this proposal? Section 2.- On the proposals of irregularities, for the Secretary of Welfare\r\n9. Based on what evaluation was it confirmed that 2 out of 3 children's stays present irregularities and what are the irregularities detected?\r\n10. What is the percentage of daycare centers by state that, based on the information available to the secretariat, operated with irregularities?\r\n11. What are the cases of corruption that have been detected in the childcare program, and how are they linked to each other?\r\n12. What are the sources of information on irregularities?\r\n13. Assuming that it is possible to prove corruption in the program, why was it decided to change the program model, instead of auditing and improving it -specifically the evaluation and institutional coordination system-? Section 3.- Regarding the current operation, for the Welfare Secretariat\r\n14. How many minors in total does the program care for, how many for each Child Care Center by entity and municipality?\r\n15. How many staff collaborate in the children's rooms registered by the secretariat? Section 4.- On the changes that the Secretary of Well-being has proposed, for the Secretary of Well-being.\r\n16. After the budget cut for the Estancias Infantiles program, how is the program expected to serve its target population?\r\n17. Has any study been carried out on the benefits and effects of the changes in the rules of operation of day care centers, in relation to the best interests of the child?\r\n18. Based on the proposal of the Secretary of the Treasury that children can be cared for by relatives, will there be specific monitoring to safeguard the integrity and rights of minors who decide not to attend childcare centers anymore?\r\n19. Currently, childcare facilities meet certain objectives for children, which help them in their development ...
#  "23. What does the government plan to do to support mothers who quit their jobs because they do not have childcare benefits?\r\n24. Will there be a call for those people who want to have access to economic subsidies in childcare centers to register, or will the resources only be delivered to those who were previously registered?\r\n25. Do you have a direct telephone line to obtain information or make a complaint?\r\n26. How will the correct application of public resources be verified or audited in favor of the 400,000 children who will benefit in early childhood? SOLE.- The Senate of the Republic requests the General Director of the Federal Electricity Commission, information from the current status of the technical and financial elements in the generation of electrical energy, as well as the causes of the increase in current electrical rates.\r\nONLY. The Permanent Commission of the H. Congress of the Union respectfully urges the Ministry of Public Education to continue making public knowledge, in a timely manner, and through its official pages, the Progress Reports and Results of the 2020 Education Sector Program -2024, in accordance with the National Development Plan 2019-2024, in order to know its scope: as well as the final versions of the free textbooks that will be implemented in the new educational model.\r\nFIRST. The Senate of the Republic respectfully urges the heads of the public security institutions of the three levels of Government to reinforce surveillance operations on the country's highways and highways in a coordinated manner, in order to combat and prevent cargo theft. SECOND. The Senate of the Republic respectfully urges the heads of the 32 state prosecutor's offices to review, and where appropriate strengthen, the mechanisms that facilitate the process of reporting cargo theft. UNIQUE. The Senate of the Republic urges the Federal Government and the Ministry of Agriculture and Rural Development so that, in coordination with the state and municipal governments, comprehensive public policies are generated aimed at the participation of young people in rural activities with a view to generational change, taking into account technical training to generate sustainable and environmentally friendly agricultural practices. UNIQUE. The Senate of the Republic respectfully urges the National Water Commission, the Municipal Government of San Miguel de Allende, Guanajuato and the Directorate of Environment and Sustainability of San Miguel de Allende, so that within the scope of their powers they coordinate and carry out the prompt and necessary actions, as well as the elaboration of a strategic plan for the removal and sustainable management of the aquatic lily plague in the Ignacio Allende Dam. Likewise, they are respectfully requested to send this Sovereignty a detailed report on the actions that are being carried out for the removal and management of the Water Lily and on the elimination of clandestine discharges in the Dam. UNIQUE. The Senate of the Republic respectfully urges the National Coordination of Civil Protection of the Secretariat of Security and Citizen Protection, to promote the coordination of efforts of the federal, state and municipal authorities, to strengthen the actions of dissemination of preventive information for the population in case of natural disasters through the various media; as well as to carry out programs of reconstruction, restoration, rehabilitation and maintenance of the physical, educational and health infrastructure, and in general support to the population affected by natural phenomena."]

# %% [markdown]
# ## Feed text through BERT model to create a summary.

# %%
#Import BERT model
model = BertModel.from_pretrained('bert-base-uncased')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]

# %%
senators["initiative_summary_en"] = ""

# %%
for index, row in senators.iterrows():
    
    if len(row["initiatives_summary_dummy_en"]) >= 1:
        
        sentences = sent_tokenize(row["initiatives_summary_dummy_en"])
        
        print(f"Working on summary {index} of {len(senators)}. This senator has {len(sentences)} sentences.")

        n = 150
        sentences_split = [sentences[i:i+n] for i in range(0, len(sentences), n)]
        summary = []
        
        for sen_split in sentences_split:
            
            print(f"Procesing batch of {len(sen_split)} sentences.")
                
            tokenized_sentences = [tokenizer.encode(sent, add_special_tokens=True) for sent in sentences]

            max_len = 0
            for i in tokenized_sentences:
                if len(i) > max_len:
                    max_len = len(i)

            padded_sentences = []
            for i in tokenized_sentences:
                while len(i) < max_len:
                    i.append(0)
                padded_sentences.append(i)

            input_ids = torch.tensor(padded_sentences)

            with torch.no_grad():
                last_hidden_states = model(input_ids)[0]

            sentence_embeddings = []
            for i in range(len(sen_split)):
                sentence_embeddings.append(torch.mean(last_hidden_states[i], dim=0).numpy())

            # Compute the similarity matrix
            similarity_matrix = cosine_similarity(sentence_embeddings)

            # Generate the summary
            num_sentences = round(len(sen_split)*.25)
            summary_sentences = []
            for i in range(num_sentences):
                sentence_scores = list(enumerate(similarity_matrix[i]))

            sentence_scores = sorted(sentence_scores, key=lambda x: x[1], reverse=True)

            for i in range(num_sentences):
                print(f"Appending summary sentence {i}")
                summary_sentences.append(sen_split[sentence_scores[i][0]])

            sub_summary = ' '.join(summary_sentences)
            
            summary.append(sub_summary)
                    
        summary = " ".join([str(item) for item in summary])

        senators.at[index, "initiative_summary_en"] = summary
        
        print(f"Summary {index} of {len(senators)} complete!")
        
    else:
        
        print(f"Senator number {index}, senator {row['senadores']} has no initiatives to summarize.")
# Out:
# Working on summary 0 of 126. This senator has 8 sentences.
# Procesing batch of 8 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Summary 0 of 126 complete!
# Working on summary 1 of 126. This senator has 65 sentences.
# Procesing batch of 65 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Summary 1 of 126 complete!
# Working on summary 2 of 126. This senator has 135 sentences.
# Procesing batch of 135 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Summary 2 of 126 complete!
# Working on summary 3 of 126. This senator has 211 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 61 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Summary 3 of 126 complete!
# Working on summary 4 of 126. This senator has 117 sentences.
# Procesing batch of 117 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Summary 4 of 126 complete!
# Working on summary 5 of 126. This senator has 429 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 129 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Summary 5 of 126 complete!
# Working on summary 6 of 126. This senator has 377 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 77 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Summary 6 of 126 complete!
# Working on summary 7 of 126. This senator has 78 sentences.
# Procesing batch of 78 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Summary 7 of 126 complete!
# Working on summary 8 of 126. This senator has 226 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 76 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Summary 8 of 126 complete!
# Working on summary 9 of 126. This senator has 364 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 64 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Summary 9 of 126 complete!
# Working on summary 10 of 126. This senator has 181 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 31 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Summary 10 of 126 complete!
# Working on summary 11 of 126. This senator has 37 sentences.
# Procesing batch of 37 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Summary 11 of 126 complete!
# Working on summary 12 of 126. This senator has 116 sentences.
# Procesing batch of 116 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Summary 12 of 126 complete!
# Working on summary 13 of 126. This senator has 89 sentences.
# Procesing batch of 89 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Summary 13 of 126 complete!
# Working on summary 14 of 126. This senator has 250 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 100 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Summary 14 of 126 complete!
# Working on summary 15 of 126. This senator has 206 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 56 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Summary 15 of 126 complete!
# Working on summary 16 of 126. This senator has 350 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 50 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Summary 16 of 126 complete!
# Working on summary 17 of 126. This senator has 111 sentences.
# Procesing batch of 111 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Summary 17 of 126 complete!
# Working on summary 18 of 126. This senator has 194 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 44 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Summary 18 of 126 complete!
# Working on summary 19 of 126. This senator has 135 sentences.
# Procesing batch of 135 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Summary 19 of 126 complete!
# Working on summary 20 of 126. This senator has 176 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 26 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Summary 20 of 126 complete!
# Working on summary 21 of 126. This senator has 76 sentences.
# Procesing batch of 76 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Summary 21 of 126 complete!
# Working on summary 22 of 126. This senator has 495 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 45 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Summary 22 of 126 complete!
# Working on summary 23 of 126. This senator has 461 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 11 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Summary 23 of 126 complete!
# Working on summary 24 of 126. This senator has 495 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 45 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Summary 24 of 126 complete!
# Working on summary 25 of 126. This senator has 365 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 65 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Summary 25 of 126 complete!
# Working on summary 26 of 126. This senator has 341 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# ...
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 7 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Summary 112 of 126 complete!
# Working on summary 113 of 126. This senator has 138 sentences.
# Procesing batch of 138 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Summary 113 of 126 complete!
# Working on summary 114 of 126. This senator has 284 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 134 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Summary 114 of 126 complete!
# Working on summary 115 of 126. This senator has 75 sentences.
# Procesing batch of 75 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Summary 115 of 126 complete!
# Working on summary 116 of 126. This senator has 190 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 40 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Summary 116 of 126 complete!
# Working on summary 117 of 126. This senator has 214 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 64 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Summary 117 of 126 complete!
# Working on summary 118 of 126. This senator has 170 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 20 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Summary 118 of 126 complete!
# Working on summary 119 of 126. This senator has 203 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 53 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Summary 119 of 126 complete!
# Working on summary 120 of 126. This senator has 101 sentences.
# Procesing batch of 101 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Summary 120 of 126 complete!
# Working on summary 121 of 126. This senator has 43 sentences.
# Procesing batch of 43 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Summary 121 of 126 complete!
# Working on summary 122 of 126. This senator has 209 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 59 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Summary 122 of 126 complete!
# Working on summary 123 of 126. This senator has 171 sentences.
# Procesing batch of 150 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Appending summary sentence 12
# Appending summary sentence 13
# Appending summary sentence 14
# Appending summary sentence 15
# Appending summary sentence 16
# Appending summary sentence 17
# Appending summary sentence 18
# Appending summary sentence 19
# Appending summary sentence 20
# Appending summary sentence 21
# Appending summary sentence 22
# Appending summary sentence 23
# Appending summary sentence 24
# Appending summary sentence 25
# Appending summary sentence 26
# Appending summary sentence 27
# Appending summary sentence 28
# Appending summary sentence 29
# Appending summary sentence 30
# Appending summary sentence 31
# Appending summary sentence 32
# Appending summary sentence 33
# Appending summary sentence 34
# Appending summary sentence 35
# Appending summary sentence 36
# Appending summary sentence 37
# Procesing batch of 21 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Summary 123 of 126 complete!
# Working on summary 124 of 126. This senator has 46 sentences.
# Procesing batch of 46 sentences.
# Appending summary sentence 0
# Appending summary sentence 1
# Appending summary sentence 2
# Appending summary sentence 3
# Appending summary sentence 4
# Appending summary sentence 5
# Appending summary sentence 6
# Appending summary sentence 7
# Appending summary sentence 8
# Appending summary sentence 9
# Appending summary sentence 10
# Appending summary sentence 11
# Summary 124 of 126 complete!
# Senator number 125, senator José Ramón Gómez Leal has no initiatives to summarize.

# %%
senators.to_csv(r'senators_data_summarized_en.csv')

# %% [markdown]
# ## Retranslate summaries back to spanish.

# %%
#Split the english summaries for each senator into bites smaller than 5000 to be able to translate back to spanish.
senators["initiatives_summary_en_split"] = ""

n = 4999

for i, row in senators.iterrows():
    if not row["initiative_list"] == []:
        summary_split_es = [row["initiative_summary_en"][i:i+n] for i in range(0, len(row["initiative_summary_en"]), n)]
        senators.at[i, "initiatives_summary_en_split"] = summary_split_es
    else:
        senators.at[i, "initiatives_summary_en_split"] = []

# %%
#Translate the split english summaires back to spanish, split string of initiatives per senator, store in new column.

senators["initiatives_summary_es_split"] = ""

for i, row in senators.iterrows():
    print(f"Working on row {i} of {len(senators)}")
    if len(row["initiatives_summary_dummy_split"]) >= 1:
        es_initiatives = GoogleTranslator(source='en', target='es').translate_batch(row["initiatives_summary_en_split"])
        senators.at[i, "initiatives_summary_es_split"] = es_initiatives
        print(f"Summary {i} translated successfully. Sample: {es_initiatives[0][:20]}")
    else:
        print(f"Senator number {i}, senator {row['senadores']} has no initiatives to translate.")
        continue
# Out:
# Working on row 0 of 126
# Summary 0 translated successfully. Sample: Propone establecer u
# Working on row 1 of 126
# Summary 1 translated successfully. Sample: Propone que este ord
# Working on row 2 of 126
# Summary 2 translated successfully. Sample: Dicho informe deberá
# Working on row 3 of 126
# Summary 3 translated successfully. Sample: Propone incorporar l
# Working on row 4 of 126
# Summary 4 translated successfully. Sample: -Registro único y pú
# Working on row 5 of 126
# Summary 5 translated successfully. Sample: Propone considerar q
# Working on row 6 of 126
# Summary 6 translated successfully. Sample: Autoriza al Congreso
# Working on row 7 of 126
# Summary 7 translated successfully. Sample: Propone que el Ejecu
# Working on row 8 of 126
# Summary 8 translated successfully. Sample: Propone homologar el
# Working on row 9 of 126
# Summary 9 translated successfully. Sample: Propone que en los c
# Working on row 10 of 126
# Summary 10 translated successfully. Sample: Propone agregar los
# Working on row 11 of 126
# Summary 11 translated successfully. Sample: La ley reglamentaria
# Working on row 12 of 126
# Summary 12 translated successfully. Sample: Propone incorporar l
# Working on row 13 of 126
# Summary 13 translated successfully. Sample: Propone garantizar q
# Working on row 14 of 126
# Summary 14 translated successfully. Sample: Además, se propone g
# Working on row 15 of 126
# Summary 15 translated successfully. Sample: Propone establecer q
# Working on row 16 of 126
# Summary 16 translated successfully. Sample: Propone el acceso a
# Working on row 17 of 126
# Summary 17 translated successfully. Sample: Propone atribuir a l
# Working on row 18 of 126
# Summary 18 translated successfully. Sample: Finalmente, establec
# Working on row 19 of 126
# Summary 19 translated successfully. Sample: Propone que el Estad
# Working on row 20 of 126
# Summary 20 translated successfully. Sample: Propone reformar el
# Working on row 21 of 126
# Summary 21 translated successfully. Sample: Propone prohibir, en
# Working on row 22 of 126
# Summary 22 translated successfully. Sample: Propone reformar el
# Working on row 23 of 126
# Summary 23 translated successfully. Sample: Propone prohibir, en
# Working on row 24 of 126
# Summary 24 translated successfully. Sample: En el mismo caso, la
# Working on row 25 of 126
# Summary 25 translated successfully. Sample: Asimismo, se aumenta
# Working on row 26 of 126
# Summary 26 translated successfully. Sample: La Junta Directiva d
# Working on row 27 of 126
# Summary 27 translated successfully. Sample: b) Promover la adopc
# Working on row 28 of 126
# Summary 28 translated successfully. Sample: Propone que se inclu
# Working on row 29 of 126
# Summary 29 translated successfully. Sample: Propone establecer q
# Working on row 30 of 126
# Summary 30 translated successfully. Sample: Asimismo, propone qu
# Working on row 31 of 126
# Summary 31 translated successfully. Sample: Precisa que este fin
# Working on row 32 of 126
# Summary 32 translated successfully. Sample: e) Controlar y dar s
# Working on row 33 of 126
# Summary 33 translated successfully. Sample: Propone establecer c
# Working on row 34 of 126
# Summary 34 translated successfully. Sample: Propone incluir en l
# Working on row 35 of 126
# Summary 35 translated successfully. Sample: Propone reformar el
# Working on row 36 of 126
# Summary 36 translated successfully. Sample: Propone establecer q
# Working on row 37 of 126
# Summary 37 translated successfully. Sample: También establece qu
# Working on row 38 of 126
# Summary 38 translated successfully. Sample: Establece que el Pre
# Working on row 39 of 126
# Summary 39 translated successfully. Sample: Por ello, también se
# Working on row 40 of 126
# Summary 40 translated successfully. Sample: Se añade también el
# Working on row 41 of 126
# Summary 41 translated successfully. Sample: Propone establecer q
# Working on row 42 of 126
# Summary 42 translated successfully. Sample: Del mismo modo, se d
# Working on row 43 of 126
# Summary 43 translated successfully. Sample: Propone establecer q
# Working on row 44 of 126
# Summary 44 translated successfully. Sample: La iniciativa tiene
# Working on row 45 of 126
# Summary 45 translated successfully. Sample: Propone establecer q
# Working on row 46 of 126
# Summary 46 translated successfully. Sample: Del mismo modo, prop
# Working on row 47 of 126
# Summary 47 translated successfully. Sample: Regular las activida
# Working on row 48 of 126
# Summary 48 translated successfully. Sample: Se añade un título d
# Working on row 49 of 126
# Summary 49 translated successfully. Sample: Las actividades que
# Working on row 50 of 126
# Summary 50 translated successfully. Sample: Asimismo, establece
# Working on row 51 of 126
# Summary 51 translated successfully. Sample: Además, propone la g
# Working on row 52 of 126
# Summary 52 translated successfully. Sample: Modifica el supuesto
# Working on row 53 of 126
# Summary 53 translated successfully. Sample: Además, definirá las
# Working on row 54 of 126
# Summary 54 translated successfully. Sample: Por otro lado, prohí
# Working on row 55 of 126
# Summary 55 translated successfully. Sample: El que cometa el del
# Working on row 56 of 126
# Summary 56 translated successfully. Sample: Propone modificar la
# Working on row 57 of 126
# Summary 57 translated successfully. Sample: También propone que,
# Working on row 58 of 126
# Summary 58 translated successfully. Sample: El Senado de la Repú
# Working on row 59 of 126
# Summary 59 translated successfully. Sample: Propone autorizar al
# Working on row 60 of 126
# Summary 60 translated successfully. Sample: Establece que los sa
# Working on row 61 of 126
# Summary 61 translated successfully. Sample: Además, propone que
# Working on row 62 of 126
# Summary 62 translated successfully. Sample: Establece que en cas
# Working on row 63 of 126
# Summary 63 translated successfully. Sample: Se adiciona el numer
# Working on row 64 of 126
# Summary 64 translated successfully. Sample: Propone establecer u
# Working on row 65 of 126
# Summary 65 translated successfully. Sample: Propone establecer s
# Working on row 66 of 126
# Summary 66 translated successfully. Sample: La iniciativa propon
# Working on row 67 of 126
# Summary 67 translated successfully. Sample: Propone expedir un n
# Working on row 68 of 126
# Summary 68 translated successfully. Sample: También se propone q
# Working on row 69 of 126
# Summary 69 translated successfully. Sample: En el caso de invali
# Working on row 70 of 126
# Summary 70 translated successfully. Sample: Propone establecer q
# Working on row 71 of 126
# Summary 71 translated successfully. Sample: Propone establecer q
# Working on row 72 of 126
# Summary 72 translated successfully. Sample: Por último, para la
# Working on row 73 of 126
# Summary 73 translated successfully. Sample: Así como establecer
# Working on row 74 of 126
# Summary 74 translated successfully. Sample: . ÚNICO. PRIMERO. PR
# Working on row 75 of 126
# Summary 75 translated successfully. Sample: También propone tipi
# Working on row 76 of 126
# Summary 76 translated successfully. Sample: Asimismo, se propone
# Working on row 77 of 126
# Summary 77 translated successfully. Sample: Se propone establece
# Working on row 78 of 126
# Summary 78 translated successfully. Sample: Propone expedir la L
# Working on row 79 of 126
# Summary 79 translated successfully. Sample: Propone establecer q
# Working on row 80 of 126
# Summary 80 translated successfully. Sample: Asimismo, propone fa
# Working on row 81 of 126
# Summary 81 translated successfully. Sample: Propone que las polí
# Working on row 82 of 126
# Senator number 82, senator Alejandro Rojas Diaz Duran has no initiatives to translate.
# Working on row 83 of 126
# Summary 83 translated successfully. Sample: Contempla la creació
# Working on row 84 of 126
# Summary 84 translated successfully. Sample: Asimismo, se estable
# Working on row 85 of 126
# Summary 85 translated successfully. Sample: Además. ÚNICO. terce
# Working on row 86 of 126
# Summary 86 translated successfully. Sample: Propone incorporar e
# Working on row 87 of 126
# Summary 87 translated successfully. Sample: Por su parte, establ
# Working on row 88 of 126
# Summary 88 translated successfully. Sample: Propone establecer q
# Working on row 89 of 126
# Summary 89 translated successfully. Sample: Asimismo, contempla
# Working on row 90 of 126
# Summary 90 translated successfully. Sample: Todo ello, en coordi
# Working on row 91 of 126
# Summary 91 translated successfully. Sample: Propone regular la p
# Working on row 92 of 126
# Summary 92 translated successfully. Sample: Además, propone supr
# Working on row 93 of 126
# Summary 93 translated successfully. Sample: La iniciativa tiene
# Working on row 94 of 126
# Summary 94 translated successfully. Sample: Propone que en la co
# Working on row 95 of 126
# Summary 95 translated successfully. Sample: Esta ley de nueva cr
# Working on row 96 of 126
# Summary 96 translated successfully. Sample: Establece quiénes se
# Working on row 97 of 126
# Summary 97 translated successfully. Sample: , además de comprend
# Working on row 98 of 126
# Summary 98 translated successfully. Sample: Propone establecer q
# Working on row 99 of 126
# Summary 99 translated successfully. Sample: Además, propone incl
# Working on row 100 of 126
# Summary 100 translated successfully. Sample: La iniciativa tiene
# Working on row 101 of 126
# Summary 101 translated successfully. Sample: Por otra parte, prop
# Working on row 102 of 126
# Summary 102 translated successfully. Sample: La ley establecerá l
# Working on row 103 of 126
# Summary 103 translated successfully. Sample: Asimismo, podrá expe
# Working on row 104 of 126
# Summary 104 translated successfully. Sample: Esta ley de nueva cr
# Working on row 105 of 126
# Summary 105 translated successfully. Sample: En ambos centros, la
# Working on row 106 of 126
# Summary 106 translated successfully. Sample: Propone que se derog
# Working on row 107 of 126
# Summary 107 translated successfully. Sample: La iniciativa se est
# Working on row 108 of 126
# Summary 108 translated successfully. Sample: Propone que por “Res
# Working on row 109 of 126
# Summary 109 translated successfully. Sample: Propone declarar el
# Working on row 110 of 126
# Summary 110 translated successfully. Sample: de sus hijos, cónyug
# Working on row 111 of 126
# Summary 111 translated successfully. Sample: - Que los créditos s
# Working on row 112 of 126
# Summary 112 translated successfully. Sample: Añade las siguientes
# Working on row 113 of 126
# Summary 113 translated successfully. Sample: Además, propone esta
# Working on row 114 of 126
# Summary 114 translated successfully. Sample: Propone garantizar e
# Working on row 115 of 126
# Summary 115 translated successfully. Sample: Propone derogar el s
# Working on row 116 of 126
# Summary 116 translated successfully. Sample: Como parte restricti
# Working on row 117 of 126
# Summary 117 translated successfully. Sample: Pretende manifestar
# Working on row 118 of 126
# Summary 118 translated successfully. Sample: Propone expedir la L
# Working on row 119 of 126
# Summary 119 translated successfully. Sample: Propone que todos lo
# Working on row 120 of 126
# Summary 120 translated successfully. Sample: Además, dicho proces
# Working on row 121 of 126
# Summary 121 translated successfully. Sample: Propone una ley de n
# Working on row 122 of 126
# Summary 122 translated successfully. Sample: Por otra parte, prop
# Working on row 123 of 126
# Summary 123 translated successfully. Sample: Lo anterior durante
# Working on row 124 of 126
# Summary 124 translated successfully. Sample: . ÚNICO. PRIMERO. SE
# Working on row 125 of 126
# Senator number 125, senator José Ramón Gómez Leal has no initiatives to translate.

# %%
#Merge translated batches into one
senators["initiative_summary_es"] = senators["initiatives_summary_es_split"].apply(lambda x: "".join(x))

# %%
#Drop senators without initiatives
senators = senators.dropna(subset=['initiative_summary_es'])

# %%
#Save file with spanish translated summary column.
senators.to_csv(r'../data/senators_data_summarized_es.csv')

# %%
senators = pd.read_csv(r"/Users/jmlunamugica/Downloads/senators_data_summarized_es.csv").fillna("")

# %%
senators = pd.read_csv(r"/Users/jmlunamugica/Downloads/senators_data_summarized_es.csv").fillna("").drop(["Unnamed: 0.1", "Unnamed: 0"], axis=1)

# %%
senators.keys()
# Out:
# Index(['senator_id', 'Apellidos', 'Nombre', 'Fraccion', 'Legislatura',
#        'Estado', 'Sexo', 'tipoEleccion', 'Suplente', 'estadoOrigen', 'correo',
#        'facebook', 'twitter', 'youtube', 'instagram', 'url_sitio', 'telefono',
#        'extension', 'estatus', 'direccion', 'id', 'senadores',
#        'attendance_score', 'initiative_list', 'initiatives_summary_dummy',
#        'initiatives_summary_dummy_split', 'initiatives_summary_dummy_split_en',
#        'initiatives_summary_dummy_en', 'initiative_summary_en',
#        'initiatives_summary_en_split', 'initiatives_summary_es_split',
#        'initiative_summary_es'],
#       dtype='object')
